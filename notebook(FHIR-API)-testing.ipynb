# %%
import requests
import json
# from pprint import pprint

headers = {
    'Accept': 'application/json+fhir'
}

params = {
    'pageContext': '35d95fe0-03bf-426c-bc35-2533f7fde4eb',
    'direction': 'NEXT',
    'subject:Patient': '1316024'
}
response = requests.get('https://fhir-open.sandboxcerner.com/dstu2/0b8a0111-e8e6-4c26-a91c-5069cbc6b1ca/Observation', headers=headers, params=params).json()

print(json.dumps(response, indent = 4, sort_keys = False))
# Out:
# {
#     "resourceType": "Bundle",
#     "id": "59c70b9b-d55e-4954-a729-29a7373884be",
#     "type": "searchset",
#     "link": [
#         {
#             "relation": "self",
#             "url": "https://fhir-open.sandboxcerner.com/dstu2/0b8a0111-e8e6-4c26-a91c-5069cbc6b1ca/Observation?patient=1316024&_count=50"
#         },
#         {
#             "relation": "next",
#             "url": "https://fhir-open.sandboxcerner.com/dstu2/0b8a0111-e8e6-4c26-a91c-5069cbc6b1ca/Observation?patient=1316024&-pageContext=174cca5e-c2f0-48d7-8d40-9670bb4ad0c5&-pageDirection=NEXT"
#         }
#     ],
#     "entry": [
#         {
#             "fullUrl": "https://fhir-open.sandboxcerner.com/dstu2/0b8a0111-e8e6-4c26-a91c-5069cbc6b1ca/Observation/27-7662151",
#             "resource": {
#                 "resourceType": "Observation",
#                 "id": "27-7662151",
#                 "meta": {
#                     "versionId": "7662151",
# ...

# %%
import requests
import json
# from pprint import pprint

headers = {
    'Accept': 'application/json+fhir'
}

params = {
    '-pageContext': '...',
    '-pageDirection': 'NEXT'
}
response = requests.get('https://fhir-open.sandboxcerner.com/dstu2/0b8a0111-e8e6-4c26-a91c-5069cbc6b1ca/Appointment', headers=headers, params=params).json()

print(json.dumps(response, indent = 4, sort_keys = False))
# Out:
# {
#     "resourceType": "Bundle",
#     "id": "c63e02e2-847e-4fda-ae99-644c0fe96953",
#     "type": "searchset",
#     "link": [
#         {
#             "relation": "self",
# ...

# %%
# pprint(response.json())

# %%
# print(json.dumps(response, indent = 4, sort_keys = False))

# %%
f = open('data.json', "w")
f.write(json.dumps(response))
f.close()
